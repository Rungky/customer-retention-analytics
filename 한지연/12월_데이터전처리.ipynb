# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/데이터톤/data/2019-Dec.csv')
df
# Out:
#                        event_time event_type  product_id          category_id  \
# 0         2019-12-01 00:00:00 UTC       view     1005105  2232732093077520756
# 1         2019-12-01 00:00:00 UTC       view    22700068  2232732091643068746
# 2         2019-12-01 00:00:01 UTC       view     2402273  2232732100769874463
# 3         2019-12-01 00:00:02 UTC   purchase    26400248  2053013553056579841
# 4         2019-12-01 00:00:02 UTC       view    20100164  2232732110089618156
# ...                           ...        ...         ...                  ...
# 67542873  2019-12-31 23:59:58 UTC       view     1005118  2232732093077520756
# 67542874  2019-12-31 23:59:58 UTC       view     1307229  2053013554658804075
# 67542875  2019-12-31 23:59:59 UTC       view     9300104  2053013554524586339
# 67542876  2019-12-31 23:59:59 UTC       view     4803759  2232732079706079299
# 67542877  2019-12-31 23:59:59 UTC       view     1005132  2232732093077520756
#
# ...

# %% [markdown]
# ### 데이터 구조 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67542878 entries, 0 to 67542877
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 4.5+ GB

# %%
df['event_type'].value_counts()
# Out:
# event_type
# view        62986067
# cart         3394763
# purchase     1162048
# Name: count, dtype: int64

# %% [markdown]
# ### 카테고리는 1162개

# %%
df['category_id'].value_counts()
# Out:
# category_id
# 2232732093077520756    16259284
# 2232732099754852875     2097755
# 2232732079706079299     2007297
# 2053013554658804075     1374333
# 2053013553199186187     1311399
#                          ...
# 2160098698049093979           1
# 2059484602015154495           1
# 2155114836386644747           1
# 2195742276976640352           1
# 2166891935262835680           1
# Name: count, Length: 1162, dtype: int64

# %% [markdown]
# ### 제품은 20만개

# %%
df['product_id'].value_counts()
# Out:
# product_id
# 1004767      828790
# 1004856      669105
# 1005115      580804
# 1005100      401870
# 1005160      391577
#               ...
# 100062441         1
# 100025194         1
# 100064275         1
# 100062444         1
# 35100812          1
# Name: count, Length: 205230, dtype: int64

# %% [markdown]
# ### 카테고리 분류를 만들 수 있는 경우 값이 있음(없다면 NaN)

# %%
df['category_code'].value_counts()
# Out:
# category_code
# construction.tools.light            16519261
# electronics.clocks                   2740539
# appliances.personal.massager         2613517
# apparel.shoes                        2543026
# appliances.kitchen.refrigerators     2401372
#                                       ...
# appliances.environment.fan              5354
# appliances.kitchen.microwave            3615
# computers.components.sound_card         3470
# auto.accessories.light                   633
# country_yard.furniture.bench               1
# Name: count, Length: 135, dtype: int64

# %% [markdown]
# ### 브랜드는 약 4637개 있는 것으로 확인

# %%
df['brand'].value_counts()
# Out:
# brand
# samsung        8540399
# apple          5594757
# xiaomi         5208639
# huawei         1903123
# lucente        1269502
#                 ...
# thefaceshop          1
# waspo                1
# linda                1
# zodiak               1
# rev                  1
# Name: count, Length: 4637, dtype: int64

# %% [markdown]
# ### 세션 컬럼 확인

# %%
df[['event_time', 'user_session']].value_counts()
# Out:
# event_time               user_session
# 2019-12-05 13:38:47 UTC  a76e625c-a40e-4f70-b86a-6a053c82dd39    82
# 2019-12-08 06:03:11 UTC  48f76873-001d-4188-b0b3-248aa686d31f    54
# 2019-12-24 09:11:23 UTC  8642a887-ffbe-476e-ba46-c081b5628e9e    52
# 2019-12-08 06:00:26 UTC  48f76873-001d-4188-b0b3-248aa686d31f    51
# 2019-12-19 06:12:49 UTC  005048f9-f0df-445f-8676-8bfa624a6f07    47
#                                                                  ..
# 2019-12-13 21:48:36 UTC  a9403b59-91ce-4300-92fd-582c1881face     1
#                          a4087735-6475-473d-8908-a3aba1b5cf80     1
#                          9a76cfe9-fcf6-44cc-a600-988d0047e377     1
#                          510a1a05-8e34-4b1b-88c7-9a499689b43a     1
# 2019-12-13 21:48:37 UTC  32809964-52f2-4527-ac85-2f4f100519ca     1
# Name: count, Length: 67374595, dtype: int64

# %% [markdown]
# ### 컬럼별 결측치 비율 확인

# %%
# 결측치 비율 계산
missing_ratio = df.isnull().mean().sort_values(ascending=False)

# 결측치 비율이 있는 컬럼만 보기 (선택사항)
missing_ratio = missing_ratio[missing_ratio > 0]

# 결과 출력
print("결측치 비율 (%):")
print((missing_ratio * 100).round(2))
# Out:
# 결측치 비율 (%):
# brand            12.03
# category_code    10.50
# user_session      0.00
# dtype: float64

# %%
df.isna().sum()
# Out:
# event_time             0
# event_type             0
# product_id             0
# category_id            0
# category_code    7088848
# brand            8122410
# price                  0
# user_id                0
# user_session          21
# dtype: int64

# %%
df_null = df[df.isnull().any(axis=1)]
df_null
# Out:
#                        event_time event_type  product_id          category_id  \
# 1         2019-12-01 00:00:00 UTC       view    22700068  2232732091643068746
# 3         2019-12-01 00:00:02 UTC   purchase    26400248  2053013553056579841
# 6         2019-12-01 00:00:02 UTC       view    21400264  2053013561579406073
# 9         2019-12-01 00:00:04 UTC       view    26205399  2232732081585127530
# 12        2019-12-01 00:00:05 UTC       view    22700202  2232732091643068746
# ...                           ...        ...         ...                  ...
# 67542837  2019-12-31 23:59:40 UTC       view    12713435  2053013553199186187
# 67542854  2019-12-31 23:59:51 UTC       view    26200609  2232732081585127530
# 67542856  2019-12-31 23:59:52 UTC       view     6600979  2053013552662315243
# 67542863  2019-12-31 23:59:54 UTC       view    16000546  2232732083690668195
# 67542868  2019-12-31 23:59:56 UTC       view    26018374  2053013561059312345
#
# ...

# %% [markdown]
# ### 날짜형식 변환

# %%
# datetime 형식으로 되어 있어야 함
df['event_time'] = pd.to_datetime(df['event_time'])

# event_date를 datetime으로 변환 (안정성 확보)
df['event_date'] = pd.to_datetime(df['event_time'].dt.date)

# 시간 컬럼 생성 (00시 단위까지만)
df['event_hour'] = df['event_time'].dt.hour

df
# Out:
#                         event_time event_type  product_id  \
# 0        2019-12-01 00:00:00+00:00       view     1005105
# 1        2019-12-01 00:00:00+00:00       view    22700068
# 2        2019-12-01 00:00:01+00:00       view     2402273
# 3        2019-12-01 00:00:02+00:00   purchase    26400248
# 4        2019-12-01 00:00:02+00:00       view    20100164
# ...                            ...        ...         ...
# 67542873 2019-12-31 23:59:58+00:00       view     1005118
# 67542874 2019-12-31 23:59:58+00:00       view     1307229
# 67542875 2019-12-31 23:59:59+00:00       view     9300104
# 67542876 2019-12-31 23:59:59+00:00       view     4803759
# 67542877 2019-12-31 23:59:59+00:00       view     1005132
#
#                   category_id                  category_code   brand    price  \
# 0         2232732093077520756       construction.tools.light   apple  1302.48
# 1         2232732091643068746                            NaN   force   102.96
# ...
